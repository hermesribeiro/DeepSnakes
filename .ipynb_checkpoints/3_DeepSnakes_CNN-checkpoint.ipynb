# %% [markdown]
# # Deep Snakes
# by Hermes, Channel and Jeanne. Rio de Janeiro, Brazil, 2018.
#
# ## Welcome to project Deep Snakes
#
# In this series, we will try different machine learning approaches to identify two classes of snakes; python snakes (family pythonidae) and rattlesnakes (genera crotalus and sistrurus).

# %% [markdown]
# ## Convolutional Neural Networks
# In the previous notebook, we developed and tuned a shallow neural network, finishing with an error analysis, showing that most errors had no apparend causes. In this notebook, we will try to address this issues by building a deeper architecture.

# %%
download = False
if download:  
  # !pip install -U -q PyDrive

  from pydrive.auth import GoogleAuth
  from pydrive.drive import GoogleDrive
  from google.colab import auth
  from oauth2client.client import GoogleCredentials

  # 1. Authenticate and create the PyDrive client.
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

  # 2. Download the intended files
  filenames = ["train_set.hdf5","dev_set.hdf5","supporting_functions_colab.py"]
  for name in filenames:
    print("Loading: ", name)
    file_list = drive.ListFile({'q': "title='{}' and trashed=false".format(name)}).GetList()
    file = drive.CreateFile({'id': file_list[0]['id']})
    file.GetContentFile(name)
  print("Done!")

# %%
# !ls
# Out:
# bestfit.hdf5  __pycache__		     supporting_functions_colab.py
# checkpoint    save_best.data-00000-of-00001  train_set.hdf5
# datalab       save_best.index
# dev_set.hdf5  save_best.meta

# %% [markdown]
# ## Loading the dataset

# %%
import numpy as np
import h5py as h5
import tensorflow as tf
from supporting_functions_colab import snake_data
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
images_train_orig, labels_train_orig, images_dev_orig, labels_dev_orig = snake_data()
print("Shapes")
print("Images train:", images_train_orig.shape)
print("Labels train:", labels_train_orig.shape)
print("Images dev:", images_dev_orig.shape)
print("Labels dev:", labels_dev_orig.shape)
# Out:
# Shapes
# Images train: (484, 128, 128, 3)
# Labels train: (484,)
# Images dev: (121, 128, 128, 3)
# Labels dev: (121,)

# %% [markdown]
# This time we don't need to linearize the dataset, we will only normalize it and set the vector dimensions straight.

# %%
images_train = images_train_orig/255
labels_train = (labels_train_orig).reshape(-1,1)
images_dev = images_dev_orig/255
labels_dev = (labels_dev_orig).reshape(-1,1)
imsize = images_train.shape[1:3] # image_shape
dsize = images_train.shape[0] # amount of images
dsize_dev = images_dev.shape[0] # amount of dev images
print("Shapes")
print("Images train:", images_train.shape)
print("Labels train:", labels_train.shape)
print("Images dev:", images_dev.shape)
print("Labels dev:", labels_dev.shape)
# Out:
# Shapes
# Images train: (484, 128, 128, 3)
# Labels train: (484, 1)
# Images dev: (121, 128, 128, 3)
# Labels dev: (121, 1)

# %% [markdown]
# ## Building the model
# ### Convolutional Neural Networks
# Convolutional Neural Networks (CNN) are made by (as the name suggests), convolutional layers.  The first operation is convolving the image with filters in order to generate a 3D affine transformation matrix, followed by an activation function to compute an activation matrix. Optinionally,  these layers ends with a pooling operation to reduce the matrix size along the first two axes. Using a sequence of convolutional layers  has the incredible advantage of exponencially increasing the NN's expressive power, which brings about two major advantages: less parameters and better accuracy, compared to a shalow (but wide) fully connected model.
#
# Typically, as we go deeper into the model architecture, the height and width of the activation matrix decreases while the lenght increases. The last layer is usually a 1D flattened layer. So, we will start with two layers, followed by a fully connected layer and increase the model's complexity as needed.

# %%
def model_builder(cparams,hparams):
    # Builds the models placeholders for inputs and outputs, parameter variables and feed forward computation graph.
    # Argument: cparams - constant params, meaning, input/output dimensions.
    #           hparams - hyperparameters, meaning, hyperparameters. All of them.
    # Returns: tf objects regarding X, Y, logits and costs. Will handle weights on the next fcn.
    #
    # getting win, hin, nout (inputs width and height, output # of classes)
    win = cparams["win"]
    hin = cparams["hin"]
    nout = cparams["nout"]
    # getting f1,c1,f2,c2. Stride on filters will be 1 for what it's worth
    f1 = hparams["f1"] # filter size of conv 1
    c1 = hparams["c1"] # num channels(filters) conv 1
    f2 = hparams["f2"] # there are 2 typoe of people in the world
    c2 = hparams["c2"] # those who can extrapolate from incomplete information.
    # getting p1, sp2 (pooling layers sizes, will consider size=stride)
    p1 = hparams["p1"]
    p2 = hparams["p2"]
    # planting the seed
    tf.set_random_seed(2001) # a space odissey
    # creating placeholders
    X = tf.placeholder(dtype=tf.float32,shape=[None,win,hin,3],name="X")
    Y = tf.placeholder(dtype=tf.float32,shape=[None,nout],name="Y")
    # first layer
    conv_1 = tf.layers.conv2d(X,kernel_size=f1,filters=c1,name="conv_1",padding="SAME")
    act_1 = tf.nn.relu(conv_1)
    pool_1 = tf.layers.max_pooling2d(act_1,pool_size=p1,strides=p1)
    # second layer
    conv_2 = tf.layers.conv2d(pool_1,kernel_size=f2,filters=c2,name="conv_2",padding="SAME")
    act_2 = tf.nn.relu(conv_2)
    pool_2 = tf.layers.max_pooling2d(act_2,pool_size=p2,strides=p2)
    # flatten
    flat = tf.layers.flatten(pool_2)
    # logits (activation is already None, brilliant!)
    logits = tf.layers.dense(flat,nout,name="logits")
    # cost
    cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=Y))
    # If we need the parameter values later, we will return it. For now, let's do all things within TemsorFlow
    return X, Y,logits, cost

# %% [markdown]
# Training the model. For minibatch split, we will try a different approach. Previously, when the number of samples was not divisible by the (mini)batch size, we split the data into n chunks, where n-1 were equally sized and the last one contained the remaining data. Now, we will use numpy `array_split`:
# >For an array of length l that should be split into n sections, it returns l % n sub-arrays of size l//n + 1 and the rest of size l//n.
#
# Therefore, `batch_size` will no longer be constant, but bounded below by its value and upper bounded by `batch_size+1`. This may bring about some computational efficiency issue, but will minimize some effect cused by the last mini_batch being smaller than the rest.

# %%
def model_trainer(hparams, 
                  images_train = images_train, # Problematic if used incorrectly.
                  labels_train = labels_train, # watch out!
                  images_dev = images_dev, 
                  labels_dev = labels_dev, 
                  print_every=5):
    # Since CNN has a ton of hyperparameters, there will be no default value.
    tf.set_random_seed(42) # the answer to life the universe and everything
    np.random.seed(42) # Is this a valid turing test question tho? 
    # number of train and dev samples
    n_train = images_train.shape[0]
    n_dev = images_dev.shape[0]
    # Retrieving hyperparameters
    epochs = hparams["epochs"]
    learning_rate = hparams["learning_rate"]
    batch_size = hparams["batch_size"]
    num_batches = n_train//batch_size
    # determining cparams
    cparams = {"hin":images_train.shape[1], 
               "win":images_train.shape[2], 
               "nout":labels_train.shape[1]}
    # building the model
    X,Y,logits,cost = model_builder(cparams,hparams)
    # bulding the floppy disc icon
    saver = tf.train.Saver(max_to_keep = 1)
    # defining the optimizer
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)
    # I'm sessy and I know it!
    with tf.Session() as sess: 
        # Performance variables container
        costs_train = []
        costs_dev = []
        cost_dev_best = float("inf")
        # indices
        indices = np.arange(n_train) 
        # note to self: don't use n or m, use explicit names. Almost screwed everything up.
        # Starting the global variables
        init = tf.global_variables_initializer()
        sess.run(init)        
        for epoch in range(epochs+1): # epochs+1 to facilitate print_every
            # everyday I'm shufflin
            indices = np.random.permutation(indices)
            splits = np.array_split(indices,num_batches)
            cost_train = 0.
            # running mini batches
            for split in splits:
                _,temp_cost = sess.run([optimizer,cost],feed_dict={X:images_train[split],Y:labels_train[split]})
                cost_train += temp_cost/num_batches
            # storing train cost
            costs_train.append(cost_train)
            # computing dev cost
            dev_splits = np.array_split(np.arange(images_dev.shape[0]),images_dev.shape[0]/batch_size)
            cost_dev=0.
            # will divide into samples to minimize mamory usage
            samples = np.array_split(np.arange(n_dev),n_dev/16)
            for sample in samples:
                cost_dev += sess.run(cost, feed_dict={X:images_dev[sample],Y:labels_dev[sample]})/(n_dev/16)
            costs_dev.append(cost_dev)
            # saver
            if cost_dev < cost_dev_best:
                saver.save(sess,"./save_best")
                cost_dev_best = cost_dev
            # print output
            if not epoch%print_every:
                print("Epoch {}: train cost = {:6.4f}, dev cost = {:6.4f}".format(epoch,cost_train,cost_dev))
        return costs_train, costs_dev

# %% [markdown]
# Run Lola run!

# %%
# %%time
tf.reset_default_graph()
# f1 = filter 1 size, c1 = number of channels (filters), p1 = size of pooling
hparams = {"f1":5, "c1":10, "p1":4,
           "f2":3, "c2":20, "p2":2,
           "epochs":100,
           "learning_rate":1.e-5, 
           "batch_size":4}
costs_train, costs_dev = model_trainer(hparams, print_every=1)
# Out:
# Epoch 0: train cost = 0.6937, dev cost = 0.6451
# Epoch 1: train cost = 0.6919, dev cost = 0.6436
# Epoch 2: train cost = 0.6907, dev cost = 0.6424
# Epoch 3: train cost = 0.6893, dev cost = 0.6417
# Epoch 4: train cost = 0.6884, dev cost = 0.6411
# Epoch 5: train cost = 0.6874, dev cost = 0.6404
# Epoch 6: train cost = 0.6864, dev cost = 0.6394
# Epoch 7: train cost = 0.6859, dev cost = 0.6387
# Epoch 8: train cost = 0.6849, dev cost = 0.6383
# Epoch 9: train cost = 0.6837, dev cost = 0.6378
# Epoch 10: train cost = 0.6830, dev cost = 0.6372
# Epoch 11: train cost = 0.6817, dev cost = 0.6363
# Epoch 12: train cost = 0.6806, dev cost = 0.6359
# Epoch 13: train cost = 0.6798, dev cost = 0.6354
# Epoch 14: train cost = 0.6786, dev cost = 0.6344
# Epoch 15: train cost = 0.6774, dev cost = 0.6336
# Epoch 16: train cost = 0.6761, dev cost = 0.6328
# Epoch 17: train cost = 0.6750, dev cost = 0.6318
# Epoch 18: train cost = 0.6734, dev cost = 0.6308
# Epoch 19: train cost = 0.6719, dev cost = 0.6296
# Epoch 20: train cost = 0.6703, dev cost = 0.6284
# Epoch 21: train cost = 0.6692, dev cost = 0.6273
# Epoch 22: train cost = 0.6675, dev cost = 0.6261
# Epoch 23: train cost = 0.6655, dev cost = 0.6245
# Epoch 24: train cost = 0.6641, dev cost = 0.6232
# Epoch 25: train cost = 0.6627, dev cost = 0.6217
# Epoch 26: train cost = 0.6606, dev cost = 0.6207
# Epoch 27: train cost = 0.6589, dev cost = 0.6189
# Epoch 28: train cost = 0.6573, dev cost = 0.6183
# Epoch 29: train cost = 0.6553, dev cost = 0.6164
# Epoch 30: train cost = 0.6537, dev cost = 0.6147
# Epoch 31: train cost = 0.6520, dev cost = 0.6131
# Epoch 32: train cost = 0.6496, dev cost = 0.6115
# Epoch 33: train cost = 0.6478, dev cost = 0.6097
# Epoch 34: train cost = 0.6456, dev cost = 0.6082
# Epoch 35: train cost = 0.6436, dev cost = 0.6063
# Epoch 36: train cost = 0.6416, dev cost = 0.6047
# Epoch 37: train cost = 0.6391, dev cost = 0.6036
# Epoch 38: train cost = 0.6376, dev cost = 0.6023
# Epoch 39: train cost = 0.6361, dev cost = 0.6000
# Epoch 40: train cost = 0.6333, dev cost = 0.5988
# Epoch 41: train cost = 0.6320, dev cost = 0.5976
# Epoch 42: train cost = 0.6296, dev cost = 0.5958
# Epoch 43: train cost = 0.6280, dev cost = 0.5945
# Epoch 44: train cost = 0.6263, dev cost = 0.5938
# Epoch 45: train cost = 0.6254, dev cost = 0.5916
# Epoch 46: train cost = 0.6226, dev cost = 0.5907
# Epoch 47: train cost = 0.6211, dev cost = 0.5891
# Epoch 48: train cost = 0.6195, dev cost = 0.5884
# Epoch 49: train cost = 0.6175, dev cost = 0.5871
# Epoch 50: train cost = 0.6164, dev cost = 0.5849
# Epoch 51: train cost = 0.6142, dev cost = 0.5846
# Epoch 52: train cost = 0.6129, dev cost = 0.5840
# Epoch 53: train cost = 0.6108, dev cost = 0.5826
# Epoch 54: train cost = 0.6096, dev cost = 0.5806
# Epoch 55: train cost = 0.6079, dev cost = 0.5790
# Epoch 56: train cost = 0.6066, dev cost = 0.5774
# Epoch 57: train cost = 0.6057, dev cost = 0.5785
# Epoch 58: train cost = 0.6034, dev cost = 0.5758
# Epoch 59: train cost = 0.6023, dev cost = 0.5752
# Epoch 60: train cost = 0.6002, dev cost = 0.5733
# Epoch 61: train cost = 0.5988, dev cost = 0.5720
# Epoch 62: train cost = 0.5968, dev cost = 0.5711
# Epoch 63: train cost = 0.5955, dev cost = 0.5695
# Epoch 64: train cost = 0.5940, dev cost = 0.5681
# Epoch 65: train cost = 0.5926, dev cost = 0.5670
# Epoch 66: train cost = 0.5918, dev cost = 0.5664
# Epoch 67: train cost = 0.5892, dev cost = 0.5657
# Epoch 68: train cost = 0.5877, dev cost = 0.5662
# Epoch 69: train cost = 0.5862, dev cost = 0.5639
# Epoch 70: train cost = 0.5841, dev cost = 0.5629
# Epoch 71: train cost = 0.5829, dev cost = 0.5612
# Epoch 72: train cost = 0.5810, dev cost = 0.5604
# Epoch 73: train cost = 0.5801, dev cost = 0.5603
# Epoch 74: train cost = 0.5783, dev cost = 0.5567
# Epoch 75: train cost = 0.5772, dev cost = 0.5576
# Epoch 76: train cost = 0.5750, dev cost = 0.5562
# Epoch 77: train cost = 0.5737, dev cost = 0.5546
# Epoch 78: train cost = 0.5717, dev cost = 0.5554
# Epoch 79: train cost = 0.5710, dev cost = 0.5557
# Epoch 80: train cost = 0.5688, dev cost = 0.5527
# Epoch 81: train cost = 0.5674, dev cost = 0.5514
# Epoch 82: train cost = 0.5660, dev cost = 0.5506
# Epoch 83: train cost = 0.5646, dev cost = 0.5513
# Epoch 84: train cost = 0.5640, dev cost = 0.5497
# Epoch 85: train cost = 0.5624, dev cost = 0.5484
# Epoch 86: train cost = 0.5605, dev cost = 0.5482
# Epoch 87: train cost = 0.5585, dev cost = 0.5498
# Epoch 88: train cost = 0.5581, dev cost = 0.5477
# Epoch 89: train cost = 0.5560, dev cost = 0.5454
# Epoch 90: train cost = 0.5562, dev cost = 0.5476
# Epoch 91: train cost = 0.5544, dev cost = 0.5474
# Epoch 92: train cost = 0.5533, dev cost = 0.5441
# Epoch 93: train cost = 0.5522, dev cost = 0.5446
# Epoch 94: train cost = 0.5510, dev cost = 0.5462
# Epoch 95: train cost = 0.5509, dev cost = 0.5454
# Epoch 96: train cost = 0.5486, dev cost = 0.5425
# Epoch 97: train cost = 0.5489, dev cost = 0.5417
# Epoch 98: train cost = 0.5464, dev cost = 0.5431
# Epoch 99: train cost = 0.5462, dev cost = 0.5415
# Epoch 100: train cost = 0.5465, dev cost = 0.5434
# CPU times: user 1min 1s, sys: 25 s, total: 1min 26s
# Wall time: 1min 15s

# %% [markdown]
# Using saved values to predict and calculate accuracy.

# %%
def metrics(hparams,
            images_train = images_train, # same as before: tread lightly
            labels_train = labels_train,
            images_dev = images_dev,
            labels_dev = labels_dev):
    # Function to calculate the predicted values and the accuracies on the dataset.
    # determining cparams
    cparams = {"hin":images_train.shape[1], 
               "win":images_train.shape[2], 
               "nout":labels_train.shape[1]}
    # This function uses a tensorflow graph instead of numpy
    tf.reset_default_graph()
    with tf.Session() as sess:
        # building the same model used in prediction
        X,Y,logits,cost = model_builder(cparams,hparams)
        # loading the weights and biases that rendered the smallest dev error
        saver = tf.train.Saver()
        saver.restore(sess,"./save_best")
        # Building the graphs to calculate pred and accuracy
        pred = tf.sigmoid(logits)
        n_train = images_train.shape[0]
        n_dev = images_dev.shape[0]
        # iterating over the train set
        cost_train = 0.
        splits = np.array_split(np.arange(n_train),n_train//16)
        pred_train = np.zeros([n_train,1])
        for split in splits:
            # calculating the train cost again
            cost_train += sess.run(cost, feed_dict={X:images_train[split],Y:labels_train[split]})/(n_train/16)
            pred_train[split] = sess.run(pred, feed_dict={X:images_train[split],Y:labels_train[split]})
        # iterating on the dev set
        cost_dev = 0.
        pred_dev = np.zeros([n_dev,1])
        splits = np.array_split(np.arange(n_dev),n_dev//16)
        for split in splits:
            # calculating the dev cost again.
            cost_dev += sess.run(cost, feed_dict={X:images_dev[split],Y:labels_dev[split]})/(n_dev/16)
            pred_dev[split] = sess.run(pred,feed_dict={X:images_dev[split],Y:labels_dev[split]})
    # using numpy for less verbosity
    acc_train = np.mean(np.equal(np.greater(pred_train,0.5).astype(int),labels_train))
    acc_dev = np.mean(np.equal(np.greater(pred_dev,0.5).astype(int),labels_dev))
    return cost_train,cost_dev,pred_train,pred_dev,acc_train,acc_dev

# %%
cost_train,cost_dev,pred_train,pred_dev,acc_train,acc_dev = metrics(hparams)
print("At dev cost = {:6.4f}: Accuracy train = {:6.4f}, Accuracy dev = {:6.4f}".format(cost_dev,acc_train,acc_dev))
# Out:
# INFO:tensorflow:Restoring parameters from ./save_best
# At dev cost = 0.5415: Accuracy train = 0.7562, Accuracy dev = 0.7355

# %%
train_curve, = plt.plot(costs_train, label = 'Train error')
test_curve,  = plt.plot(costs_dev, label = 'Dev error')
plt.legend(handles=[train_curve,test_curve])
plt.xlabel('Epochs')
plt.ylabel('Mean log loss')
plt.show()

# %% [markdown]
# Just by increasing the number of layers, and obviously using the artifacts available on CNN, the model was 2% higher in accuracy and the dev error decreased considerably.  Funny thing is that there are 1000 times less parameters (7.701) than shallow NN (7.864.800).

# %% [markdown]
# As fun as it is to create models using tensorflow, we will switch to keras. Although tensorflow is a bit faster, we can build models with less lines and iterate quickly through various approaches. We will draw inspiration from major modelling techniques like: AlexNet, Googlenet, ResNet and even make moonshots to ResNeXt.

# %% [markdown]
# ### AlexNet
# [AlexNet](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf) is the pioneer deep learning architecture. Developed by Alex Krizhevsky, Ilya Sutskever and the godfather of Deep Learning, Geofrey Hinton, this algorithm won the ILSVR 2012 competition by a large marging, proving that deep learning was the top technique for image classification and localization.
#
# Alexnet hidden layer architecture is made of eight layers, five convolutional and two fully connected with the following characteristic:
# * 96 kernels (filters) of size 11x11x3 with a stride of 4 pixels;
#     * Response normalization
#     * Pooling (size 3, stride 2)
# * 256 kernels of size 5x5x96
#     * Response normalization
#     * Pooling (size 3, stride 2)
# * 384 kernels of size 3x3x256
# * 384 kernels of size 3x3x384
# * 256 kernels of size 3x3x384
# * Two consecutive fully connected layers with 4096 neurons each
#     * With dropout rate of 0.5
#
# Our problem differs from the original problem it solves in two aspects. First, the input images were 224x224x3 pixels, while our problem images are 128x128x3 pixels. Second, the original problem was a classification with 1000 possible classes, therefore, the output layer has 1000 neurons. In our problem, there are only 2 possible outputs, therefore, our output layer has only 1 neuron.
# Therefore, we will build a similar architecture considering the difference between both problems.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Dense, Dropout, Flatten, Activation
from keras import optimizers
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
np.random.seed(1564)
tf.set_random_seed(1564)
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
# LAYER 1
# The actual model used padding = 3. Will use sequential model with padding="same"
model.add(Conv2D(48,11,strides=(4,4),padding='same',input_shape=(128,128,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(3,2))
# LAYER 2
model.add(Conv2D(128,5,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(3,2))
# LAYER 3
model.add(Conv2D(192,3,padding='same',activation='relu'))
# LAYER 4
model.add(Conv2D(192,3,padding='same',activation='relu'))
# LAYER 5
model.add(Conv2D(192,3,padding='same',activation='relu'))
# LAYER 6
model.add(Flatten())
model.add(Dense(2048,activation='relu'))
model.add(Dropout(0.5))
# LAYER 7
model.add(Dense(2048,activation='relu'))
model.add(Dropout(0.5))
# OUTPUT
model.add(Dense(1,activation='sigmoid'))

# %%
def reset_weights(model):
    session = K.get_session()
    for layer in model.layers: 
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel.initializer.run(session=session)

# %%
# %%time
adam = optimizers.Adam(lr=1e-6)
SGD = optimizers.SGD(lr=1e-6) # Didn't perform well
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])
reset_weights(model)
hist = model.fit(images_train, labels_train, epochs=100, batch_size=4, validation_data=(images_dev,labels_dev), verbose=2)
# Out:
# Train on 484 samples, validate on 121 samples
# Epoch 1/100
#  - 6s - loss: 0.7404 - acc: 0.5103 - val_loss: 0.6899 - val_acc: 0.4959
# Epoch 2/100
#  - 5s - loss: 0.7258 - acc: 0.4773 - val_loss: 0.6867 - val_acc: 0.5207
# Epoch 3/100
#  - 5s - loss: 0.7046 - acc: 0.5145 - val_loss: 0.6809 - val_acc: 0.5372
# Epoch 4/100
#  - 5s - loss: 0.6970 - acc: 0.5351 - val_loss: 0.6769 - val_acc: 0.5455
# Epoch 5/100
#  - 5s - loss: 0.6748 - acc: 0.5868 - val_loss: 0.6751 - val_acc: 0.5289
# Epoch 6/100
#  - 5s - loss: 0.7149 - acc: 0.5083 - val_loss: 0.6708 - val_acc: 0.5455
# Epoch 7/100
#  - 5s - loss: 0.6823 - acc: 0.5661 - val_loss: 0.6649 - val_acc: 0.5537
# Epoch 8/100
#  - 5s - loss: 0.6647 - acc: 0.5950 - val_loss: 0.6615 - val_acc: 0.5537
# Epoch 9/100
#  - 5s - loss: 0.6669 - acc: 0.6136 - val_loss: 0.6585 - val_acc: 0.5785
# Epoch 10/100
#  - 5s - loss: 0.6598 - acc: 0.5971 - val_loss: 0.6543 - val_acc: 0.5950
# Epoch 11/100
#  - 5s - loss: 0.6679 - acc: 0.5723 - val_loss: 0.6500 - val_acc: 0.6033
# Epoch 12/100
#  - 5s - loss: 0.6723 - acc: 0.5785 - val_loss: 0.6479 - val_acc: 0.5950
# Epoch 13/100
#  - 5s - loss: 0.6486 - acc: 0.6240 - val_loss: 0.6435 - val_acc: 0.5950
# Epoch 14/100
#  - 5s - loss: 0.6496 - acc: 0.6157 - val_loss: 0.6421 - val_acc: 0.5950
# Epoch 15/100
#  - 5s - loss: 0.6526 - acc: 0.6136 - val_loss: 0.6417 - val_acc: 0.5868
# Epoch 16/100
#  - 5s - loss: 0.6373 - acc: 0.6322 - val_loss: 0.6363 - val_acc: 0.5620
# Epoch 17/100
#  - 5s - loss: 0.6374 - acc: 0.6405 - val_loss: 0.6338 - val_acc: 0.5537
#  - 5s - loss: 0.2628 - acc: 0.9132 - val_loss: 0.6381 - val_acc: 0.6860
# Epoch 94/100
#  - 5s - loss: 0.2490 - acc: 0.9318 - val_loss: 0.6391 - val_acc: 0.6694
# Epoch 95/100
#  - 5s - loss: 0.2390 - acc: 0.9256 - val_loss: 0.6402 - val_acc: 0.6777
# Epoch 96/100
#  - 5s - loss: 0.2370 - acc: 0.9360 - val_loss: 0.6436 - val_acc: 0.6777
# Epoch 97/100
#  - 5s - loss: 0.2298 - acc: 0.9277 - val_loss: 0.6487 - val_acc: 0.6777
# Epoch 98/100
#  - 5s - loss: 0.2324 - acc: 0.9360 - val_loss: 0.6757 - val_acc: 0.6942
# Epoch 99/100
#  - 5s - loss: 0.2300 - acc: 0.9174 - val_loss: 0.6435 - val_acc: 0.6860
# Epoch 100/100
#  - 5s - loss: 0.2288 - acc: 0.9277 - val_loss: 0.6680 - val_acc: 0.6942
# CPU times: user 5min 25s, sys: 4min 10s, total: 9min 36s
# Wall time: 8min 50s

# %%
best_epoch = np.argmax(hist.history['val_acc'])
cost_train = hist.history['loss'][best_epoch]
cost_dev = hist.history['val_loss'][best_epoch]
acc_train = hist.history['acc'][best_epoch]
acc_dev = hist.history['val_acc'][best_epoch]
print("Epoch {}".format(best_epoch))
print(" - loss: {:6.4f} - acc: {:6.4f} - val_loss: {:6.4f} - val_acc: {:6.4f}".format(cost_train,acc_train,cost_dev,acc_dev))
# Out:
# Epoch 55
#  - loss: 0.4467 - acc: 0.7872 - val_loss: 0.6047 - val_acc: 0.6942

# %%
train_curve, = plt.plot(hist.history['loss'], label = 'Train error')
test_curve,  = plt.plot(hist.history['val_loss'], label = 'Dev error')
plt.legend(handles=[train_curve,test_curve])
plt.xlabel('Epochs')
plt.ylabel('Mean log loss')
plt.show()

# %%
# %%time
batch_size = 4
epochs = 500
adam = optimizers.Adam(lr=1e-6) # didn't perform well
sgd = optimizers.SGD(lr=1e-4)
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])
reset_weights(model)
datagen = ImageDataGenerator(#rotation_range=40, 
                             width_shift_range=0.2, 
                             height_shift_range=0.2, 
                             #shear_range=0.2, 
                             zoom_range=0.2, 
                             #channel_shift_range=10, 
                             horizontal_flip=True, 
                             fill_mode='nearest')

datagen.fit(images_train)

checkpointer = ModelCheckpoint(filepath='bestfit.hdf5', 
                               #verbose=1, 
                               save_best_only=True, 
                               monitor='val_acc')

hist = model.fit_generator(datagen.flow(images_train,labels_train,batch_size), 
                           steps_per_epoch=int(dsize/batch_size), 
                           epochs=epochs, 
                           validation_data=(images_dev,labels_dev),
                           verbose=2, 
                           use_multiprocessing=True, 
                           callbacks=[checkpointer])
# Out:
# Epoch 1/500
#  - 5s - loss: 0.7570 - acc: 0.4938 - val_loss: 0.6920 - val_acc: 0.4959
# Epoch 2/500
#  - 4s - loss: 0.7217 - acc: 0.5083 - val_loss: 0.6815 - val_acc: 0.5702
# Epoch 3/500
#  - 4s - loss: 0.7197 - acc: 0.4731 - val_loss: 0.6832 - val_acc: 0.5289
# Epoch 4/500
#  - 4s - loss: 0.3247 - acc: 0.8574 - val_loss: 0.4758 - val_acc: 0.8347
# Epoch 484/500
#  - 4s - loss: 0.2837 - acc: 0.8864 - val_loss: 1.0215 - val_acc: 0.6364
# Epoch 485/500
#  - 4s - loss: 0.3000 - acc: 0.8719 - val_loss: 0.4888 - val_acc: 0.7934
# Epoch 486/500
#  - 4s - loss: 0.2876 - acc: 0.8802 - val_loss: 1.4867 - val_acc: 0.5455
# Epoch 487/500
#  - 4s - loss: 0.3154 - acc: 0.8595 - val_loss: 0.4964 - val_acc: 0.8099
# Epoch 488/500
#  - 4s - loss: 0.3132 - acc: 0.8698 - val_loss: 0.4988 - val_acc: 0.8264
# Epoch 489/500
#  - 4s - loss: 0.2998 - acc: 0.8884 - val_loss: 1.1267 - val_acc: 0.5868
# Epoch 490/500
#  - 4s - loss: 0.3091 - acc: 0.8492 - val_loss: 1.3332 - val_acc: 0.6281
# Epoch 491/500
#  - 4s - loss: 0.3059 - acc: 0.8616 - val_loss: 0.8559 - val_acc: 0.6694
# Epoch 492/500
#  - 4s - loss: 0.3197 - acc: 0.8595 - val_loss: 0.4760 - val_acc: 0.8264
# Epoch 493/500
#  - 4s - loss: 0.3086 - acc: 0.8698 - val_loss: 0.4831 - val_acc: 0.8347
# Epoch 494/500
#  - 4s - loss: 0.2896 - acc: 0.8698 - val_loss: 0.6478 - val_acc: 0.7438
# Epoch 495/500
#  - 4s - loss: 0.2981 - acc: 0.8678 - val_loss: 0.5309 - val_acc: 0.8264
# Epoch 496/500
#  - 4s - loss: 0.3022 - acc: 0.8698 - val_loss: 0.8801 - val_acc: 0.6942
# Epoch 497/500
#  - 4s - loss: 0.3520 - acc: 0.8409 - val_loss: 0.6897 - val_acc: 0.7273
# Epoch 498/500
#  - 4s - loss: 0.3071 - acc: 0.8574 - val_loss: 0.4936 - val_acc: 0.8182
# Epoch 499/500
#  - 4s - loss: 0.3200 - acc: 0.8492 - val_loss: 0.4996 - val_acc: 0.8099
# Epoch 500/500
#  - 4s - loss: 0.3011 - acc: 0.8678 - val_loss: 0.5001 - val_acc: 0.8347
# CPU times: user 20min 57s, sys: 10min 33s, total: 31min 30s
# Wall time: 30min 39s

# %%
best_epoch = np.argmax(hist.history['val_acc'])
cost_train = hist.history['loss'][best_epoch]
cost_dev = hist.history['val_loss'][best_epoch]
acc_train = hist.history['acc'][best_epoch]
acc_dev = hist.history['val_acc'][best_epoch]
print("Epoch {}".format(best_epoch))
print(" - loss: {:6.4f} - acc: {:6.4f} - val_loss: {:6.4f} - val_acc: {:6.4f}".format(cost_train,acc_train,cost_dev,acc_dev))
# Out:
# Epoch 427
#  - loss: 0.3249 - acc: 0.8698 - val_loss: 0.4720 - val_acc: 0.8512

# %%
train_curve, = plt.plot(hist.history['loss'], label = 'Train error')
test_curve,  = plt.plot(hist.history['val_loss'], label = 'Dev error')
plt.legend(handles=[train_curve,test_curve])
plt.xlabel('Epochs')
plt.ylabel('Mean log loss')
plt.show()
